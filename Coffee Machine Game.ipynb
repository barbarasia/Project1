# %%
# define rooms and items

data_room = {
    "name": "data room",
    "type": "room",
}

ux_room = {
    "name": "ux room",
    "type": "room",
}

toilet = {
    "name": "toilet",
    "type": "room",
}

web_room = {
    "name": "web room",
    "type": "room",
}

hall = {
    "name": "hall",
    "type": "room",
} 

kitchen = {
    "name": "kitchen",
    "type": "room",
}

outside = {
    "name": "outside",
    "type": "room",
}

door_a = {
    "name": "door a",
    "type": "door",
}

door_b = {
    "name": "door b",
    "type": "door",
}

door_c = {
    "name": "door c",
    "type": "door",
}

door_d = {
    "name": "door d",
    "type": "door",
}

door_e = {
    "name": "door e",
    "type": "door",
}

door_f = {
    "name": "door f",
    "type": "door",
}

door_g = {
    "name": "door g",
    "type": "door",
}

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}

key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
}

key_e = {
    "name": "key for door e",
    "type": "key",
    "target": door_e,
}

key_f = {
    "name": "key for door f",
    "type": "key",
    "target": door_f,
}

key_g = {
    "name": "key for door g",
    "type": "key",
    "target": door_g,
}

tv_set = {
    "name": "tv set",
    "type": "furniture",
}

yoga_ball = {
    "name": "yoga ball",
    "type": "furniture",
}

painting = {
    "name": "painting",
    "type": "furniture",
}

chair = {
    "name": "chair",
    "type": "furniture",
}

toilet_seat = {
    "name": "toilet seat",
    "type": "furniture",
}

computer = {
    "name": "computer",
    "type": "furniture",
}

desk = {
    "name": "desk",
    "type": "furniture",
}

table_one = {
    "name": "table one",
    "type": "furniture",
}

table_two = {
    "name": "table two",
    "type": "furniture",
}

sofa = {
    "name": "sofa",
    "type": "furniture",
}

fridge = {
    "name": "fridge",
    "type": "furniture",
}

dishwasher = {
    "name": "dishwasher",
    "type": "furniture",
}

coffee_machine = {
    "name": "coffee machine",
    "type": "target",
}

all_rooms = [data_room, ux_room, toilet, web_room, hall, kitchen, outside]

all_doors = [door_a, door_b, door_c, door_d, door_e, door_f, door_g]

# define which items/rooms are related

object_relations = {
    "data room": [yoga_ball, tv_set, door_a, door_b],
    "ux room": [painting, chair, door_b, door_d],
    "toilet": [toilet_seat, door_d, door_f],
    "web room": [desk, computer, door_a, door_c],
    "hall": [sofa, table_one, table_two, door_c, door_e, door_g],
    "kitchen": [fridge, dishwasher, coffee_machine, door_e, door_f],
    "outside": [door_g],

    "tv set": [key_a],
    "yoga ball": [key_b],
    "desk": [key_c],
    "painting": [key_d],
    "sofa": [key_e],
    "toilet seat": [key_f],
    "table two": [key_g],

    "door a": [data_room, web_room],
    "door b": [data_room, ux_room],
    "door c": [web_room, hall],
    "door d": [ux_room, toilet],
    "door e": [hall, kitchen],
    "door f": [toilet, kitchen],
    "door g": [hall, outside],
}

# define game state. Do not directly change this dict. 
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This 
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": data_room,
    "keys_collected": [],
}

# %%
def linebreak():
    """
    Print a line break
    """
    print("\n\n")

# Step 1: Start the game
def start_game():
    """
    Start the game
    """
    print("It's break time! You need a coffee. Make your way to the kitchen!")
    play_room(game_state["current_room"])

# Step 2: Display information about the room and ask to examine it
def play_room(room):
    """
    Play a room. Let player examine the items in the room.
    """
    game_state["current_room"] = room

    print("You are now in " + room["name"])

    # Display information about the items in the room
    items = [i["name"] for i in object_relations[room["name"]]]
    print("You can see " + ", ".join(items))
        
    examine_item(input("What would you like to examine?").strip())
        
    linebreak()

# Figure out which room is behind the unlocked door
def get_next_room_of_door(door, current_room):
    """
    From object_relations, find the two rooms connected to the given door.
    Return the room that is not the current_room.
    """
    connected_rooms = object_relations[door["name"]]
    for room in connected_rooms:
        if(not current_room == room):
            return room

# Step 3: Examine a door or a piece of furniture to
# unlock a door, open a door, or check out an uninteresting furniture,
# or make yourself some coffee and win the game
def examine_item(item_name):
    """
    Examine an item which can be a door or furniture.
    First, make sure the intended item belongs to the current room.
    Then, check if the item is the coffee machine.
    If it is, the game will end with success. Otherwise, 
    check if the item is a door. Tell player if key hasn't been 
    collected yet. Otherwise ask player if they want to go to the next
    room. If the item is not a door, then check if it contains keys.
    Collect the key if found and update the game state. At the end,
    play either the current or the next room depending on the game state
    to keep playing.

    """
    current_room = game_state["current_room"]
    next_room = ""
    output = None

    for item in object_relations[current_room["name"]]:
        if(item["name"] == item_name):
            output = "You examine " + item_name + ". "
            if(item["type"] == "target"):
                output += "You drink a cup of coffee."
            elif(item["type"] == "door"):
                have_key = False
                for key in game_state["keys_collected"]:
                    if(key["target"] == item):
                        have_key = True
                if(have_key):
                    output += "You unlock it with a key you have."
                    next_room = get_next_room_of_door(item, current_room)
                else:
                    output += "It is locked but you don't have the key."
            else:
                if(item["name"] in object_relations and len(object_relations[item["name"]])>0):
                    item_found = object_relations[item["name"]].pop()
                    game_state["keys_collected"].append(item_found)
                    output += "You find " + item_found["name"] + "."
                else:
                    output += "There isn't anything interesting about it."
            print(output)
            break
    
    if(output is None):
        print("The item you requested is not found in the current room.")
    
    # Win the game
    # if player interacts with coffee machine : "Congrats ! you've won the game !"
    if(item_name == "coffee machine"):
        print("Congrats! You've won the game !")
    elif(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'):
        play_room(next_room)
    else:
        play_room(current_room)

# %%
game_state = INIT_GAME_STATE.copy()

start_game()
# Out:
# It's break time! You need a coffee. Make your way to the kitchen!
# You are now in data room
# You can see yoga ball, tv set, door a, door b
# You examine tv set. You find key for door a.
# You are now in data room
# You can see yoga ball, tv set, door a, door b
# You examine door a. You unlock it with a key you have.
# You are now in web room
# You can see desk, computer, door a, door c
# You examine computer. There isn't anything interesting about it.
# You are now in web room
# You can see desk, computer, door a, door c
# You examine desk. You find key for door c.
# You are now in web room
# You can see desk, computer, door a, door c
# You examine door a. You unlock it with a key you have.
# You are now in data room
# You can see yoga ball, tv set, door a, door b
# You examine yoga ball. You find key for door b.
# You are now in data room
# You can see yoga ball, tv set, door a, door b
# You examine door b. You unlock it with a key you have.
# You are now in ux room
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8d6f8b0f-14ef-4f9c-ab15-e26e1b243809' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
